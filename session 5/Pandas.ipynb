# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
# DataFrame
df = pd.read_csv("./IRIS.csv")

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# convert DF -> numpy
iris = pd.read_csv("IRIS.csv").values

# %%
# iris[:, :-1]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
type(df['species'])
# Out:
# pandas.core.series.Series

# %%
df[['sepal_length', 'sepal_width']]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
pd.Series([1,10,20,30], index="a b c d".split())
# Out:
# a     1
# b    10
# c    20
# d    30
# dtype: int64

# %%
arr = np.random.randint(1, 100, size=(175,3))

# %%
pd.DataFrame(arr[:, :-1], columns=['f1', 'f2'])
# Out:
#      f1  f2
# 0    27  40
# 1    68  64
# 2     2  35
# 3     1  22
# 4    99  50
# ..   ..  ..
# 170  52  95
# 171  27   3
# 172  31  48
# 173  97   9
# 174  76  80
#
# [175 rows x 2 columns]

# %%
# dataframe from a dictionary

# %%
df.iloc[1]
# Out:
# sepal_length            4.9
# sepal_width               3
# petal_length            1.4
# petal_width             0.2
# species         Iris-setosa
# Name: 1, dtype: object

# %%
df.iloc[:3]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['total_value']  = df['sepal_length'] + df['sepal_width'] + df['petal_length'] + df['petal_width']

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      total_value
# 0           10.2
# 1            9.5
# 2            9.4
# ...

# %%
df.drop(columns=['total_value'], inplace= True)
#df.drop('total_value', axis=1 , inplace = True)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# to check nan values
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df['species'].nunique()
# Out:
# 3

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
# extract all rows where you have setosa flower

# %%
df[ df['species'] == 'Iris-setosa' ]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
# extract all rows where sepal_len < 5.3
df[(df['sepal_length'] <5.3) & (df['sepal_width']>3.5)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 19           5.1          3.8           1.5          0.3  Iris-setosa
# 21           5.1          3.7           1.5          0.4  Iris-setosa
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 32           5.2          4.1           1.5          0.1  Iris-setosa
# 44           5.1          3.8           1.9          0.4  Iris-setosa
# 46           5.1          3.8           1.6          0.2  Iris-setosa

# %%
rows = np.random.randint(1,150,  100)
cols = np.random.randint(0, 4, 100)

# %%
rows
# Out:
# array([105, 131,  11, 143, 129, 127, 120,  96, 138, 110,  73, 114, 112,
#         27,  74,  91,  48,  18, 114,  92,  29,  22,  13,  88, 103, 106,
#         51,  66, 121,  12,  28,  84, 137, 123,  64, 134, 122,  59,  62,
#        112,  60,  74,  90,  54,  55,  62, 134,  27, 107,   4, 146,  79,
#         22, 100,  58,  48,  33, 105, 116,  57,  63,  86, 148,  53,  50,
#         52,  14, 122, 101, 131,  37, 129, 101,  48,  52, 144,  53, 128,
#         24,  50,  20,   1, 141, 125,  20,  20,  95,  33,  70, 116,  20,
#         83,  78,  52, 100,  50,  67,  33, 125, 126])

# %%
cols
# Out:
# array([2, 0, 0, 2, 3, 3, 2, 3, 2, 0, 1, 2, 2, 3, 0, 0, 3, 1, 2, 1, 1, 2,
#        1, 3, 1, 3, 1, 2, 2, 3, 0, 1, 2, 1, 2, 3, 2, 0, 2, 3, 1, 3, 2, 3,
#        1, 1, 2, 1, 1, 3, 1, 1, 3, 2, 0, 2, 1, 0, 2, 3, 2, 2, 3, 2, 2, 3,
#        1, 3, 0, 0, 3, 1, 0, 0, 3, 2, 2, 0, 2, 1, 2, 3, 3, 2, 0, 2, 0, 1,
#        0, 0, 3, 2, 2, 3, 0, 2, 2, 0, 2, 2])

# %%
# Manually entering NaN values

for i in range(100):
    df.iloc[rows[i], cols[i]] = np.nan

# %%
df[:50]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          NaN  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          NaN  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           NaN          3.4           1.6          0.2  Iris-setosa
# ...

# %%
df.isna().sum()
# Out:
# sepal_length    18
# sepal_width     20
# petal_length    30
# petal_width     22
# species          0
# dtype: int64

# %% [markdown]
# # Dealing with Nan Values
# - remove row
# - remove col
# - impute NaN Values (Mean)

# %%
df['sepal_length'].mean()
# Out:
# 5.813636363636366

# %%
df['sepal_length'].fillna( value=df['sepal_length'].mean()  , inplace=True)

# %%
df.isna().sum()
# Out:
# sepal_length     0
# sepal_width     20
# petal_length    30
# petal_width     22
# species          0
# dtype: int64

# %%
df.iloc[[2,7,3,8,1,9,80]]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 2            4.7          3.2           1.3          0.2      Iris-setosa
# 7            5.0          3.4           1.5          0.2      Iris-setosa
# 3            4.6          3.1           1.5          0.2      Iris-setosa
# 8            4.4          2.9           1.4          0.2      Iris-setosa
# 1            4.9          3.0           1.4          NaN      Iris-setosa
# 9            4.9          3.1           1.5          0.1      Iris-setosa
# 80           5.5          2.4           3.8          1.1  Iris-versicolor
